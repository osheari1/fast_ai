# %% [markdown]
# The purpose of this notebook is to document the model building process

# %% [markdown]
# ## Attempt 1

# %% [markdown]
# #### FineTune

# %% [markdown]
# valid set = 2000

# %% [markdown]
# finetune lr = 0.1

# %% [markdown]
# finetune epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 3: val_acc = 0.95, train_acc = 0.9548

# %% [markdown]
# #### Dense/Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.001

# %% [markdown]
# epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.957
# kaggle score = 0.157

# %% [markdown]
# ## Attempt 2

# %% [markdown]
# #### FineTune

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.001

# %% [markdown]
# epochs = 1

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.9695

# %% [markdown]
# train_acc = 0.9562

# %% [markdown]
# #### Dense Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.0001

# %% [markdown]
# epochs = 1

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.97

# %% [markdown]
# train_acc = 0.9707

# %% [markdown]
# #### Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.00001

# %% [markdown]
# epochs = 1

# %% [markdown]
# layers = 30:

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.8735

# %% [markdown]
# train_acc = 0.9735

# %% [markdown]
# ## Attempt 3

# %% [markdown]
# #### FineTune

# %% [markdown]
# lr Adam = 0.001

# %% [markdown]
# epochs = 2

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 1: val_acc = 0.9720, train_acc = 0.9550

# %% [markdown]
# Epoch 2: val_acc = 0.9740, train_acc = 0.9674

# %% [markdown]
# #### Dense Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.0001

# %% [markdown]
# epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 1: val_acc = 0.968, train_acc = 0.9663

# %% [markdown]
# Epoch 2: val_acc = 0.9720, train_acc = 0.9693

# %% [markdown]
# Epoch 3: val_acc = 0.9740, train_acc = 0.9692

# %% [markdown]
# #### Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.00001

# %% [markdown]
# epochs = 1

# %% [markdown]
# layers 30:

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 1: val_acc = 0.9765, train_acc = 0.9729

# %% [markdown]
# Kaggle score = 0.09048

# %% [markdown]
# ## Remove Dropout

# %% [markdown]
# #### ft Weights Retrain 1

# %% [markdown]
# Use ft weights from attempt 3

# %% [markdown]
# lr Adam = 0.00001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 8: val_loss = 0.0975, train_loss = 0.0972, val_acc = 0.9735, train_acc = 0.9709

# %% [markdown]
# Kaggle score = 0.09451

# %% [markdown]
# #### ft Weights Retrain 2

# %% [markdown]
# Use ft weights from attempt 3

# %% [markdown]
# lr Adam = 0.000001

# %% [markdown]
# epochs = 1

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 1: val_loss = 0.1030, train_loss = 0.1102, val_acc = 0.9720, train_acc = 0.9695

# %% [markdown]
# Kaggle score = 0.09451

# %% [markdown]
# #### conv Weights Retrain

# %% [markdown]
# Use conv weights from attempt 3

# %% [markdown]
# lr Adam = 0.000001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 1 (best): val_loss = 0.1147, train_loss = 0.1098, val_acc = 0.9750, train_acc = 0.9740

# %% [markdown]
# Kaggle score = 0.09451

# %% [markdown]
# ## Data Aug

# %% [markdown]
# Load convs weights from attempt 3

# %% [markdown]
# Data Augmentation:
# - rotation_range=15
# - width_shift_range=0.1
# - height_shift_range=0.1
# - shear_range=0.05
# - zoom_range=0.1
# - channel_shift_range=3.0
# - horizontal_flip=True
# - fill_mode='constant'

# %% [markdown]
# lr Adam = 0.00001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 6 (best): val_loss = 0.1074, train_loss = 0.0880, val_acc = 0.9755, train_acc = 0.9734
