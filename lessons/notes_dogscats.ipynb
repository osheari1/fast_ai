# %% [markdown]
# The purpose of this notebook is to document the model building process

# %% [markdown]
# ## Attempt 1

# %% [markdown]
# #### FineTune

# %% [markdown]
# valid set = 2000

# %% [markdown]
# finetune lr = 0.1

# %% [markdown]
# finetune epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 3: val_acc = 0.95, train_acc = 0.9548

# %% [markdown]
# #### Dense/Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.001

# %% [markdown]
# epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.957
# kaggle score = 0.157

# %% [markdown]
# ## Attempt 2

# %% [markdown]
# #### FineTune

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.001

# %% [markdown]
# epochs = 1

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.9695

# %% [markdown]
# train_acc = 0.9562

# %% [markdown]
# #### Dense Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.0001

# %% [markdown]
# epochs = 1

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.97

# %% [markdown]
# train_acc = 0.9707

# %% [markdown]
# #### Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.00001

# %% [markdown]
# epochs = 1

# %% [markdown]
# layers = 30:

# %% [markdown]
# ##### Results

# %% [markdown]
# val_acc = 0.8735

# %% [markdown]
# train_acc = 0.9735

# %% [markdown]
# ## Attempt 3

# %% [markdown]
# #### FineTune

# %% [markdown]
# lr Adam = 0.001

# %% [markdown]
# epochs = 2

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 1: val_acc = 0.9720, train_acc = 0.9550

# %% [markdown]
# Epoch 2: val_acc = 0.9740, train_acc = 0.9674

# %% [markdown]
# #### Dense Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.0001

# %% [markdown]
# epochs = 3

# %% [markdown]
# ##### Results

# %% [markdown]
# Epoch 1: val_acc = 0.968, train_acc = 0.9663

# %% [markdown]
# Epoch 2: val_acc = 0.9720, train_acc = 0.9693

# %% [markdown]
# Epoch 3: val_acc = 0.9740, train_acc = 0.9692

# %% [markdown]
# #### Conv Retrain

# %% [markdown]
# optimizer = Adam

# %% [markdown]
# lr = 0.00001

# %% [markdown]
# epochs = 1

# %% [markdown]
# layers 30:

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 1: val_acc = 0.9765, train_acc = 0.9729

# %% [markdown]
# Kaggle score = 0.09048

# %% [markdown]
# Use conv weights from attempt 3

# %% [markdown]
# ## Attempt 4 - Remove Dropout

# %% [markdown]
# #### From weights_conv.h5

# %% [markdown]
# Fine tune fc model from attempt3/weights_conv.h5 checkpints

# %% [markdown]
# dropout p = 0

# %% [markdown]
# lr Adam = 0.00001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 1 (best): val_loss = 0.0998, train_loss = 0.1049, val_acc = 0.9748, train_acc = 0.9755

# %% [markdown]
# Kaggle score = 0.09103

# %% [markdown]
# ## Attempt 5 - Remove Dropout, Data Aug

# %% [markdown]
# Fine tune fc model from attempt3/weights_conv.h5 checkpints

# %% [markdown]
# Weights not properly adjusted after dropout removed

# %% [markdown]
# Data Augmentation:
# - rotation_range=15
# - width_shift_range=0.1
# - height_shift_range=0.1
# - shear_range=0.05
# - zoom_range=0.1
# - channel_shift_range=3.0
# - horizontal_flip=True
# - fill_mode='constant'

# %% [markdown]
# lr Adam = 0.00001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 6 (best): val_loss = 0.1074, train_loss = 0.0880, val_acc = 0.9755, train_acc = 0.9734

# %% [markdown]
# Kaggle score = 0.08864

# %% [markdown]
# ## Attempt 6 - Remove Dropout, Data Aug

# %% [markdown]
# Fine tune fc model from attempt3/weights_conv.h5 checkpoints

# %% [markdown]
# Data Augmentation:
# - rotation_range=15
# - width_shift_range=0.1
# - height_shift_range=0.1
# - shear_range=0.05
# - zoom_range=0.1
# - channel_shift_range=3.0
# - horizontal_flip=True
# - fill_mode='constant'

# %% [markdown]
# lr Adam = 0.00001

# %% [markdown]
# epochs = 8

# %% [markdown]
# ##### Results

# %% [markdown]
# epoch 6 (best): val_loss = 0.0779, train_loss = 0.0823, val_acc = 0.9745, train_acc = 0.9719

# %% [markdown]
# Kaggle score = 0.08864
