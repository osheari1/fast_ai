# %%
import numpy as np
import pandas as pd

import os, shutil, importlib
import utils; importlib.reload(utils)
from glob import glob




# %matplotlib inline
np.set_printoptions(precision=4, linewidth=100)

# %%
path = '../../data/catsdogs/'
classes = ['cat', 'dog']

struct_dir(path, classes)
